# %% [markdown]
# ##### From the file "crawler4piotroski_fscore_selenium"

# %% [markdown]
# => flipping stock codes

# %%
# importing packages 
from datetime import datetime

import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

# sqlalchemy packages 
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, Numeric, String, DateTime, ForeignKey
from sqlalchemy.orm import sessionmaker, relationship, backref
from sqlalchemy.ext.declarative import declarative_base

# %%
# Headless Chrome
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')

# %%
# Start Chrome with Selenium
driver = webdriver.Chrome('/Users/daesikkim/Downloads/chromedriver', chrome_options=options)
driver.implicitly_wait(3)

# %%
# Get the stock data from DB(postgresql)
db_string = "postgresql://daesik:@localhost/db_piotroski"

engine = create_engine(db_string, echo=True)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
Base = declarative_base()

# %%
# Mapping 
class Stock(Base): 
    __tablename__ = 'stocks'
    
    stock_id = Column(Integer, primary_key=True)
    stock_code = Column(String, unique=True, nullable=False, primary_key=True)
    company = Column(String, index=True, unique=True, nullable=False)
    market_type = Column(Integer)
    industry = Column(String) 
    created_on = Column(DateTime, default=datetime.utcnow)
    updated_on = Column(DateTime, default=datetime.utcnow)
    
    base_param = relationship('BaseParam', back_populates='stock')
    bookmarket_param = relationship('BookMarketParam', back_populates='stock')
    
    # def __repr__(self):
    #    return "<Stock ==> id : {0}, code : {1}, company : {2}, market_type : {3}, created : {4}, updated : {5}>".format(self.stock_id, 
    #                                                                                                                     self.stock_code, 
    #                                                                                                                     self.company,
    #                                                                                                                     self.market_type,
    #                                                                                                                     self.created_on,
    #                                                                                                                     self.updated_on,)

# %%
class BaseParam(Base): 
    __tablename__ = 'base_params'
    
    baseparam_id = Column(Integer, primary_key=True)
    stock_code = Column(String, ForeignKey('stocks.stock_code'))
    date = Column(DateTime)
    price_open = Column(Integer)
    price_close = Column(Integer) 
    price_high = Column(Integer)
    price_low = Column(Integer)
    quant = Column(Integer)
    market_sum = Column(Integer)
    
    stock = relationship("Stock", back_populates="base_param")

# %%
class BookMarketParam(Base): 
    __tablename__ = 'bookmarket_params'
    
    bookmarketparam_id = Column(Integer, primary_key=True)
    stock_code = Column(String, ForeignKey('stocks.stock_code'))
    listed_stock_cnt = Column(Integer)
    property_total = Column(Integer)
    debt_total = Column(Integer)
    pbr = Column(Integer)
    
    stock = relationship('Stock', back_populates='bookmarket_param')

# %%
Base.metadata.create_all(engine)
# Out:
# 2017-10-08 22:51:17,271 INFO sqlalchemy.engine.base.Engine select version()
# 2017-10-08 22:51:17,272 INFO sqlalchemy.engine.base.Engine {}
# 2017-10-08 22:51:17,277 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2017-10-08 22:51:17,279 INFO sqlalchemy.engine.base.Engine {}
# 2017-10-08 22:51:17,285 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2017-10-08 22:51:17,290 INFO sqlalchemy.engine.base.Engine {}
# 2017-10-08 22:51:17,296 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2017-10-08 22:51:17,297 INFO sqlalchemy.engine.base.Engine {}
# 2017-10-08 22:51:17,304 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2017-10-08 22:51:17,309 INFO sqlalchemy.engine.base.Engine {}
# 2017-10-08 22:51:17,313 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-10-08 22:51:17,319 INFO sqlalchemy.engine.base.Engine {'name': 'stocks'}
# 2017-10-08 22:51:17,328 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-10-08 22:51:17,331 INFO sqlalchemy.engine.base.Engine {'name': 'base_params'}
# 2017-10-08 22:51:17,336 INFO sqlalchemy.engine.base.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2017-10-08 22:51:17,339 INFO sqlalchemy.engine.base.Engine {'name': 'bookmarket_params'}

# %%
code_n_name = session.query(Stock.stock_code, Stock.company).all()
# Out:
# 2017-10-08 22:51:19,801 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2017-10-08 22:51:19,805 INFO sqlalchemy.engine.base.Engine SELECT stocks.stock_code AS stocks_stock_code, stocks.company AS stocks_company
# FROM stocks
# 2017-10-08 22:51:19,808 INFO sqlalchemy.engine.base.Engine {}

# %%
code_n_name
# Out:
# [('005930', '삼성전자'),
#  ('000660', 'SK하이닉스'),
#  ('005935', '삼성전자우'),
#  ('005380', '현대차'),
#  ('005490', 'POSCO'),
#  ('051910', 'LG화학'),
#  ('035420', 'NAVER'),
#  ('028260', '삼성물산'),
#  ('015760', '한국전력'),
#  ('055550', '신한지주'),
#  ('105560', 'KB금융'),
#  ('032830', '삼성생명'),
#  ('207940', '삼성바이오로직스'),
#  ('012330', '현대모비스'),
#  ('017670', 'SK텔레콤'),
#  ('034730', 'SK'),
#  ('096770', 'SK이노베이션'),
#  ('006400', '삼성SDI'),
#  ('090430', '아모레퍼시픽'),
#  ('033780', 'KT&amp;G'),
#  ('066570', 'LG전자'),
#  ('086790', '하나금융지주'),
#  ('003550', 'LG'),
#  ('051900', 'LG생활건강'),
#  ('010950', 'S-Oil'),
#  ('251270', '넷마블게임즈'),
#  ('018260', '삼성에스디에스'),
#  ('011170', '롯데케미칼'),
#  ('000810', '삼성화재'),
#  ('000270', '기아차'),
#  ('000030', '우리은행'),
#  ('034220', 'LG디스플레이'),
#  ('002790', '아모레G'),
#  ('036570', '엔씨소프트'),
#  ('035720', '카카오'),
#  ('010130', '고려아연'),
#  ('009540', '현대중공업'),
#  ('024110', '기업은행'),
#  ('009150', '삼성전기'),
#  ('030200', 'KT'),
#  ('035250', '강원랜드'),
#  ('161390', '한국타이어'),
#  ('021240', '코웨이'),
#  ('004020', '현대제철'),
#  ('267250', '현대로보틱스'),
#  ('006800', '미래에셋대우'),
#  ('023530', '롯데쇼핑'),
#  ('018880', '한온시스템'),
#  ('009830', '한화케미칼'),
#  ('078930', 'GS'),
#  ('088350', '한화생명'),
#  ('139480', '이마트'),
#  ('008930', '한미사이언스'),
#  ('032640', 'LG유플러스'),
#  ('069500', 'KODEX 200'),
#  ('086280', '현대글로비스'),
#  ('004800', '효성'),
#  ('001040', 'CJ'),
#  ('005830', '동부화재'),
#  ('128940', '한미약품'),
#  ('042660', '대우조선해양'),
#  ('097950', 'CJ제일제당'),
#  ('047810', '한국항공우주'),
#  ('000720', '현대건설'),
#  ('010140', '삼성중공업'),
#  ('029780', '삼성카드'),
#  ('002380', 'KCC'),
#  ('001450', '현대해상'),
#  ('036460', '한국가스공사'),
#  ('027410', 'BGF리테일'),
#  ('005940', 'NH투자증권'),
#  ('011070', 'LG이노텍'),
#  ('271560', '오리온'),
#  ('005387', '현대차2우B'),
#  ('241560', '두산밥캣'),
#  ('009240', '한샘'),
#  ('071050', '한국금융지주'),
#  ('000120', 'CJ대한통운'),
#  ('079440', '아이엔지생명'),
#  ('000880', '한화'),
#  ('012750', '에스원'),
#  ('138930', 'BNK금융지주'),
#  ('028670', '팬오션'),
#  ('016360', '삼성증권'),
#  ('003490', '대한항공'),
#  ('047040', '대우건설'),
#  ('008560', '메리츠종금증권'),
#  ('000210', '대림산업'),
#  ('088980', '맥쿼리인프라'),
#  ('007070', 'GS리테일'),
#  ('000150', '두산'),
#  ('004990', '롯데제과'),
#  ('012630', '현대산업'),
#  ('000060', '메리츠화재'),
#  ('000100', '유한양행'),
#  ('010060', 'OCI'),
#  ('006260', 'LS'),
#  ('026960', '동서'),
#  ('047050', '포스코대우'),
#  ('007310', '오뚜기'),
#  ('102110', 'TIGER 200'),
#  ('006280', '녹십자'),
#  ('011780', '금호석유'),
#  ('005385', '현대차우'),
#  ('204320', '만도'),
#  ('138040', '메리츠금융지주'),
#  ('008770', '호텔신라'),
#  ('000670', '영풍'),
#  ('028050', '삼성엔지니어링'),
#  ('030000', '제일기획'),
#  ('004370', '농심'),
#  ('069960', '현대백화점'),
#  ('006360', 'GS건설'),
#  ('051915', 'LG화학우'),
#  ('000240', '한국타이어월드와이드'),
#  ('122630', 'KODEX 레버리지'),
#  ('010620', '현대미포조선'),
#  ('003520', '영진약품'),
#  ('012450', '한화테크윈'),
#  ('120110', '코오롱인더'),
#  ('051600', '한전KPS'),
#  ('005300', '롯데칠성'),
#  ('034020', '두산중공업'),
#  ('004170', '신세계'),
#  ('139130', 'DGB금융지주'),
#  ('020150', '일진머티리얼즈'),
#  ('039490', '키움증권'),
#  ('005250', '녹십자홀딩스'),
#  ('000080', '하이트진로'),
#  ('042670', '두산인프라코어'),
#  ('001740', 'SK네트웍스'),
#  ('011210', '현대위아'),
#  ('010120', 'LS산전'),
#  ('011200', '현대상선'),
#  ('079550', 'LIG넥스원'),
#  ('090435', '아모레퍼시픽우'),
#  ('006650', '대한유화'),
#  ('011790', 'SKC'),
#  ('071840', '롯데하이마트'),
#  ('006120', 'SK케미칼'),
#  ('005440', '현대그린푸드'),
#  ('064350', '현대로템'),
#  ('057050', '현대홈쇼핑'),
#  ('103140', '풍산'),
#  ('111770', '영원무역'),
#  ('079160', 'CJ CGV'),
#  ('214320', '이노션'),
#  ('114090', 'GKL'),
#  ('161890', '한국콜마'),
#  ('003690', '코리안리'),
#  ('181710', 'NHN엔터테인먼트'),
#  ('180640', '한진칼'),
#  ('003240', '태광산업'),
#  ('003410', '쌍용양회'),
#  ('002350', '넥센타이어'),
#  ('082640', '동양생명'),
#  ('267270', '현대건설기계'),
#  ('014820', '동원시스템즈'),
#  ('069620', '대웅제약'),
#  ('017800', '현대엘리베이'),
#  ('051905', 'LG생활건강우'),
#  ('192400', '쿠쿠전자'),
#  ('153130', 'KODEX 단기채권'),
#  ('005610', 'SPC삼립'),
#  ('114800', 'KODEX 인버스'),
#  ('001120', 'LG상사'),
#  ('001430', '세아베스틸'),
#  ('192820', '코스맥스'),
#  ('001440', '대한전선'),
#  ('004000', '롯데정밀화학'),
#  ('001230', '동국제강'),
#  ('185750', '종근당'),
#  ('010780', '아이에스동서'),
#  ('148020', 'KBSTAR 200'),
#  ('093370', '후성'),
#  ('039130', '하나투어'),
#  ('003000', '부광약품'),
#  ('115390', '락앤락'),
#  ('102780', 'KODEX 삼성그룹'),
#  ('069260', '휴켐스'),
#  ('105630', '한세실업'),
#  ('089590', '제주항공'),
#  ('012510', '더존비즈온'),
#  ('145990', '삼양사'),
#  ('267260', '현대일렉트릭'),
#  ('018670', 'SK가스'),
#  ('003300', '한일시멘트'),
#  ('175330', 'JB금융지주'),
#  ('006040', '동원산업'),
#  ('003090', '대웅'),
#  ('006840', 'AK홀딩스'),
#  ('008000', '도레이케미칼'),
#  ('014680', '한솔케미칼'),
#  ('020560', '아시아나항공'),
#  ('005880', '대한해운'),
#  ('071320', '지역난방공사'),
#  ('152100', 'ARIRANG 200'),
#  ('214980', 'KODEX 단기채권PLUS'),
#  ('001060', 'JW중외제약'),
#  ('023590', '다우기술'),
#  ('081660', '휠라코리아'),
#  ('105190', 'KINDEX 200'),
#  ('002270', '롯데푸드'),
#  ('000070', '삼양홀딩스'),
#  ('029460', '케이씨텍'),
#  ('108670', 'LG하우시스'),
#  ('073240', '금호타이어'),
#  ('001680', '대상'),
#  ('034830', '한국토지신탁'),
#  ('025540', '한국단자'),
#  ('002020', '코오롱'),
#  ('020000', '한섬'),
#  ('123890', '한국자산신탁'),
#  ('066575', 'LG전자우'),
#  ('093050', 'LF'),
#  ('000640', '동아쏘시오홀딩스'),
#  ('003620', '쌍용차'),
#  ('085620', '미래에셋생명'),
#  ('049770', '동원F&amp;B'),
#  ('052690', '한전기술'),
#  ('053210', '스카이라이프'),
#  ('000370', '한화손해보험'),
#  ('003540', '대신증권'),
#  ('003470', '유안타증권'),
#  ('019680', '대교'),
#  ('009410', '태영건설'),
#  ('170900', '동아에스티'),
#  ('009970', '영원무역홀딩스'),
#  ('157450', 'TIGER 단기통안채'),
#  ('009420', '한올바이오파마'),
#  ('060980', '한라홀딩스'),
#  ('007570', '일양약품'),
#  ('064960', 'S&amp;T모티브'),
#  ('029530', '신도리코'),
#  ('069660', 'KOSEF 200'),
#  ('000990', '동부하이텍'),
#  ('002240', '고려제강'),
#  ('271980', '제일약품'),
#  ('192530', '광주은행'),
#  ('273130', 'KODEX 종합채권(AA-이상)액티브'),
#  ('003030', '세아제강'),
#  ('034310', 'NICE'),
#  ('145720', '덴티움'),
#  ('005850', '에스엘'),
#  ('037560', 'CJ헬로비전'),
#  ('226320', '잇츠한불'),
#  ('007700', 'F&amp;F'),
#  ('058650', '세아홀딩스'),
#  ('000815', '삼성화재우'),
#  ('005180', '빙그레'),
#  ('008060', '대덕전자'),
#  ('007340', '동아타이어'),
#  ('024720', '한국콜마홀딩스'),
#  ('096760', 'JW홀딩스'),
#  ('003530', '한화투자증권'),
#  ('070960', '용평리조트'),
#  ('072710', '농심홀딩스'),
#  ('001720', '신영증권'),
#  ('033920', '무학'),
#  ('042700', '한미반도체'),
#  ('002960', '한국쉘석유'),
#  ('031440', '신세계푸드'),
#  ('004490', '세방전지'),
#  ('138250', '엔에스쇼핑'),
#  ('006060', '화승인더'),
#  ('152870', '파워 200'),
#  ('000400', '롯데손해보험'),
#  ('161000', '애경유화'),
#  ('001520', '동양'),
#  ('101530', '해태제과식품'),
#  ('017390', '서울가스'),
#  ('004380', '삼익THK'),
#  ('003920', '남양유업'),
#  ('001800', '오리온홀딩스'),
#  ('017810', '풀무원'),
#  ('005500', '삼진제약'),
#  ('004430', '송원산업'),
#  ('034120', 'SBS'),
#  ('025860', '남해화학'),
#  ('005810', '풍산홀딩스'),
#  ('031430', '신세계인터내셔날'),
#  ('126560', '현대에이치씨엔'),
#  ('007810', '코리아써키트'),
#  ('009290', '광동제약'),
#  ('025620', '제이준코스메틱'),
#  ('033660', '아주캐피탈'),
#  ('210980', 'SK디앤디'),
#  ('112610', '씨에스윈드'),
#  ('014830', '유니드'),
#  ('00088K', '한화3우B'),
#  ('004130', '대덕GDS'),
#  ('102460', '이연제약'),
#  ('011810', 'STX'),
#  ('000540', '흥국화재'),
#  ('004690', '삼천리'),
#  ('252670', 'KODEX 200선물인버스2X'),
#  ('005720', '넥센'),
#  ('009450', '경동나비엔'),
#  ('006390', '현대시멘트'),
#  ('097230', '한진중공업'),
#  ('036580', '팜스코'),
#  ('016800', '퍼시스'),
#  ('213500', '한솔제지'),
#  ('249420', '일동제약'),
#  ('015350', '부산가스'),
#  ('101060', 'SBS미디어홀딩스'),
#  ('016580', '환인제약'),
#  ('079430', '현대리바트'),
#  ('241590', '화승엔터프라이즈'),
#  ('003230', '삼양식품'),
#  ('004710', '한솔테크닉스'),
#  ('010955', 'S-Oil우'),
#  ('017940', 'E1'),
#  ('196230', 'KBSTAR 단기통안채'),
#  ('001510', 'SK증권'),
#  ('008490', '서흥'),
#  ('033240', '자화전자'),
#  ('037710', '광주신세계'),
#  ('001725', '신영증권우'),
#  ('122900', '아이마켓코리아'),
#  ('000050', '경방'),
#  ('016450', '한세예스24홀딩스'),
#  ('152330', '코리아오토글라스'),
#  ('003120', '일성신약'),
#  ('094800', '맵스리얼티1'),
#  ('025000', 'KPX케미칼'),
#  ('095570', 'AJ네트웍스'),
#  ('011930', '신성이엔지'),
#  ('032350', '롯데관광개발'),
#  ('001630', '종근당홀딩스'),
#  ('000155', '두산우'),
#  ('019170', '신풍제약'),
#  ('033270', '유나이티드제약'),
#  ('000480', '조선내화'),
#  ('002320', '한진'),
#  ('003850', '보령제약'),
#  ('003060', '에이프로젠제약'),
#  ('009680', '모토닉'),
#  ('007160', '사조산업'),
#  ('030610', '교보증권'),
#  ('139280', 'TIGER 경기방어'),
#  ('077970', 'STX엔진'),
#  ('003220', '대원제약'),
#  ('002795', '아모레G우'),
#  ('008730', '율촌화학'),
#  ('084690', '대상홀딩스'),
#  ('104700', '한국철강'),
#  ('195870', '해성디에스'),
#  ('002250', '알보젠코리아'),
#  ('002990', '금호산업'),
#  ('001500', '현대차투자증권'),
#  ('007690', '국도화학'),
#  ('002390', '한독'),
#  ('002000', '한국유리'),
#  ('020760', '일진디스플'),
#  ('001200', '유진투자증권'),
#  ('092230', 'KPX홀딩스'),
#  ('015860', '일진홀딩스'),
#  ('001130', '대한제분'),
#  ('082740', '두산엔진'),
#  ('068400', 'AJ렌터카'),
#  ('002780', '진흥기업'),
#  ('010050', '우리종금'),
#  ('214390', '경보제약'),
#  ('234080', 'JW생명과학'),
#  ('002810', '삼영무역'),
#  ('183190', '아세아시멘트'),
#  ('003200', '일신방직'),
#  ('001270', '부국증권'),
#  ('500019', '신한 레버리지 WTI원유 선물 ETN(H)'),
#  ('004150', '한솔홀딩스'),
#  ('005680', '삼영전자'),
#  ('079980', '휴비스'),
#  ('003560', 'IHQ'),
#  ('001820', '삼화콘덴서'),
#  ('011760', '현대상사'),
#  ('900140', '코라오홀딩스'),
#  ('138490', '코오롱플라스틱'),
#  ('084010', '대한제강'),
#  ('005960', '동부건설'),
#  ('001780', '알루코'),
#  ('006380', '카프로'),
#  ('136490', '선진'),
#  ('009580', '무림P&amp;P'),
#  ('001940', 'KISCO홀딩스'),
#  ('004360', '세방'),
#  ('268280', '미원에스씨'),
#  ('102260', '동성코퍼레이션'),
#  ('272560', 'KBSTAR 단기국공채액티브'),
#  ('200880', '서연이화'),
#  ('078520', '에이블씨엔씨'),
#  ('081000', '일진다이아'),
#  ('017960', '한국카본'),
#  ('003570', 'S&amp;T중공업'),
#  ('001250', 'GS글로벌'),
#  ('005070', '코스모신소재'),
#  ('000140', '하이트진로홀딩스'),
#  ('214420', '토니모리'),
#  ('003070', '코오롱글로벌'),
#  ('001880', '삼호'),
#  ('044820', '코스맥스비티아이'),
#  ('005420', '코스모화학'),
#  ('210540', '디와이파워'),
#  ('000020', '동화약품'),
#  ('004700', '조광피혁'),
#  ('005950', '이수화학'),
#  ('011690', '유양디앤유'),
#  ('002030', '아세아'),
#  ('190160', 'ARIRANG 단기유동성'),
#  ('003545', '대신증권우'),
#  ('204480', 'TIGER 차이나CSI300레버리지(합성)'),
#  ('161510', 'ARIRANG 고배당주'),
#  ('000860', '강남제비스코'),
#  ('095720', '웅진씽크빅'),
#  ('036530', 'S&amp;T홀딩스'),
#  ('103130', '웅진에너지'),
#  ('263190', 'ARIRANG 단기우량채권'),
#  ('000680', 'LS네트웍스'),
#  ('004970', '신라교역'),
#  ('001390', 'KG케미칼'),
#  ('005690', '파미셀'),
#  ('008040', '사조동아원'),
#  ('000430', '대원강업'),
#  ('264900', '크라운제과'),
#  ('004870', '티웨이홀딩스'),
#  ('005090', '삼광글라스'),
#  ('001790', '대한제당'),
#  ('007210', '벽산'),
#  ('015360', '예스코'),
#  ('092200', '디아이씨'),
#  ('000320', '노루홀딩스'),
#  ('071970', 'STX중공업'),
#  ('030210', 'KTB투자증권'),
#  ('150460', 'TIGER 중국소비테마'),
#  ('039570', '아이콘트롤스'),
#  ('004250', 'NPC'),
#  ('005389', '현대차3우B'),
#  ('044450', 'KSS해운'),
#  ('004060', 'SG세계물산'),
#  ('000970', '한국주철관'),
#  ('067830', '세이브존I&amp;C'),
#  ('000390', '삼화페인트'),
#  ('229200', 'KODEX 코스닥 150'),
#  ('089470', '현대EP'),
#  ('013570', '디와이'),
#  ('001460', 'BYC'),
#  ('229640', 'LS전선아시아'),
#  ('002630', '오리엔트바이오'),
#  ('008700', '아남전자'),
#  ('001380', 'SG충방'),
#  ('071055', '한국금융지주우'),
#  ('272570', 'KBSTAR 중장기국공채액티브'),
#  ('077500', '유니퀘스트'),
#  ('016380', '동부제철'),
#  ('007660', '이수페타시스'),
#  ('000180', '성창기업지주'),
#  ('097955', 'CJ제일제당 우'),
#  ('143860', 'TIGER 헬스케어'),
#  ('084870', 'TBH글로벌'),
#  ('011160', '두산건설'),
#  ('003460', '유화증권'),
#  ('123690', '한국화장품'),
#  ('000700', '유수홀딩스'),
#  ('058430', '포스코강판'),
#  ('139260', 'TIGER 200 IT'),
#  ('004560', '현대비앤지스틸'),
#  ('103590', '일진전기'),
#  ('035150', '백산'),
#  ('168490', '한국패러랠'),
#  ('002840', '미원상사'),
#  ('012690', '모나리자'),
#  ('004440', '대림씨엔에스'),
#  ('005740', '크라운해태홀딩스'),
#  ('019440', '세아특수강'),
#  ('000490', '대동공업'),
#  ('194370', '제이에스코퍼레이션'),
#  ('002460', '화성산업'),
#  ('002150', '도화엔지니어링'),
#  ('004960', '한신공영'),
#  ('143210', '핸즈코퍼레이션'),
#  ('100250', '진양홀딩스'),
#  ('010690', '화신'),
#  ('011280', '태림포장'),
#  ('005945', 'NH투자증권우'),
#  ('017370', '우신시스템'),
#  ('012610', '경인양행'),
#  ('035000', '지투알'),
#  ('007860', '서연'),
#  ('084680', '이월드'),
#  ('002310', '아세아제지'),
#  ('017900', '광전자'),
#  ('096775', 'SK이노베이션우'),
#  ('117580', '대성에너지'),
#  ('021820', '세원정공'),
#  ('026890', '디피씨'),
#  ('001045', 'CJ우'),
#  ('016880', '웅진'),
#  ('090350', '노루페인트'),
#  ('267290', '경동도시가스'),
#  ('248170', '샘표식품'),
#  ('102280', '쌍방울'),
#  ('002360', 'SH에너지화학'),
#  ('003280', '흥아해운'),
#  ('010820', '퍼스텍'),
#  ('006405', '삼성SDI우'),
#  ('013870', '지엠비코리아'),
#  ('272580', 'TIGER 단기채권액티브'),
#  ('041650', '상신브레이크'),
#  ('006220', '제주은행'),
#  ('002600', '조흥'),
#  ('003555', 'LG우'),
#  ('013580', '계룡건설'),
#  ('004890', '동일산업'),
#  ('007980', '태평양물산'),
#  ('003160', '디아이'),
#  ('094280', '효성ITX'),
#  ('252710', 'TIGER 200선물인버스2X'),
#  ('002620', '제일파마홀딩스'),
#  ('032560', '황금에스티'),
#  ('069640', '한세엠케이'),
#  ('012200', '계양전기'),
#  ('004540', '깨끗한나라'),
#  ('130680', 'TIGER 원유선물Enhanced(H)'),
#  ('016610', '동부증권'),
#  ('009155', '삼성전기우'),
#  ('012030', '동부'),
#  ('004840', 'DRB동일'),
#  ('002450', '삼익악기'),
#  ('017180', '명문제약'),
#  ('100220', '비상교육'),
#  ('003650', '미창석유'),
#  ('000230', '일동홀딩스'),
#  ('013520', '화승알앤에이'),
#  ('003830', '대한화섬'),
#  ('027390', '한화갤러리아타임월드'),
#  ('015890', '태경산업'),
#  ('001360', '삼성제약'),
#  ('005870', '휴니드'),
#  ('033530', '세종공업'),
#  ('025560', '미래산업'),
#  ('014280', '금강공업'),
#  ('024090', '디씨엠'),
#  ('005430', '한국공항'),
#  ('014790', '한라'),
#  ('091090', '세원셀론텍'),
#  ('192090', 'TIGER 차이나CSI300'),
#  ('003480', '한진중공업홀딩스'),
#  ('273140', 'KODEX 단기변동금리부채권액티브'),
#  ('004980', '성신양회'),
#  ('005800', '신영와코루'),
#  ('000650', '천일고속'),
#  ('003960', '사조대림'),
#  ('016710', '대성홀딩스'),
#  ('005390', '신성통상'),
#  ('075180', '새론오토모티브'),
#  ('233740', 'KODEX 코스닥150 레버리지'),
#  ('092220', 'KEC'),
#  ('002300', '한국제지'),
#  ('130660', '한전산업'),
#  ('023000', '삼원강재'),
#  ('272910', 'KINDEX 중장기국공채액티브'),
#  ('009160', 'SIMPAC'),
#  ('001530', '동일방직'),
#  ('034590', '인천도시가스'),
#  ('128820', '대성산업'),
#  ('152550', '한국ANKOR유전'),
#  ('092440', '기신정기'),
#  ('004910', '조광페인트'),
#  ('028100', '동아지질'),
#  ('107590', '미원홀딩스'),
#  ('035510', '신세계 I&amp;C'),
#  ('227840', '현대코퍼레이션홀딩스'),
#  ('009310', '참엔지니어링'),
#  ('02826K', '삼성물산우B'),
#  ('002100', '경농'),
#  ('002170', '삼양통상'),
#  ('004200', '고려개발'),
#  ('006370', '대구백화점'),
#  ('168580', 'KINDEX 중국본토CSI300'),
#  ('144620', '코오롱머티리얼'),
#  ('016090', '대현'),
#  ('011700', '한신기계'),
#  ('008350', '남선알미늄'),
#  ('047400', '쌍용머티리얼'),
#  ('009440', 'KC그린홀딩스'),
#  ('006090', '사조오양'),
#  ('530013', '삼성 KTOP30 ETN'),
#  ('226490', 'KODEX 코스피'),
#  ('003080', '성보화학'),
#  ('012170', '키위미디어그룹'),
#  ('001340', '백광산업'),
#  ('000850', '화천기공'),
#  ('134380', '미원화학'),
#  ('000215', '대림산업우'),
#  ('102970', 'KODEX 증권'),
#  ('530026', '삼성 레버리지 인도 Nifty50 선물 ETN(H)'),
#  ('075580', '세진중공업'),
#  ('232080', 'TIGER 코스닥150'),
#  ('034300', '신세계건설'),
#  ('006490', '인스코비'),
#  ('251350', 'KODEX 선진국MSCI World'),
#  ('030790', '동양네트웍스'),
#  ('015230', '대창단조'),
#  ('004310', '현대약품'),
#  ('163560', '동일고무벨트'),
#  ('025750', '한솔홈데코'),
#  ('252420', 'KBSTAR 200선물인버스2X'),
#  ('053690', '한미글로벌'),
#  ('014530', '극동유화'),
#  ('012320', '경동인베스트'),
#  ('078000', '텔코웨어'),
#  ('190620', 'KINDEX 단기통안채'),
#  ('223190', 'KODEX 200가치저변동'),
#  ('085310', '엔케이'),
#  ('005750', '대림B&amp;Co'),
#  ('014710', '사조씨푸드'),
#  ('012160', '영흥철강'),
#  ('063160', '종근당바이오'),
#  ('004450', '삼화왕관'),
#  ('111110', '호전실업'),
#  ('018500', '동원금속'),
#  ('530024', '삼성 인도 Nifty50 선물 ETN(H)'),
#  ('011150', 'CJ씨푸드'),
#  ('058860', '케이티스'),
#  ('009770', '삼정펄프'),
#  ('001750', '한양증권'),
#  ('009270', '신원'),
#  ('226810', '파워 단기채'),
#  ('017040', '광명전기'),
#  ('002900', '동양물산'),
#  ('000040', 'KR모터스'),
#  ('005010', '휴스틸'),
#  ('105840', '우진'),
#  ('016590', '신대양제지'),
#  ('011000', '진원생명과학'),
#  ('011090', '에넥스'),
#  ('037270', 'YG PLUS'),
#  ('009200', '무림페이퍼'),
#  ('002880', '대유에이텍'),
#  ('267770', 'TIGER 200선물레버리지'),
#  ('058730', '동아에스텍'),
#  ('008970', '동양철관'),
#  ('023800', '인지컨트롤스'),
#  ('007110', '일신석재'),
#  ('010960', '삼호개발'),
#  ('058850', 'KTcs'),
#  ('009320', '대우부품'),
#  ('001570', '금양'),
#  ('008600', '윌비스'),
#  ('130730', 'KOSEF 단기자금'),
#  ('008260', 'NI스틸'),
#  ('049800', '우진플라임'),
#  ('006660', '삼성공조'),
#  ('004080', '신흥'),
#  ('091170', 'KODEX 은행'),
#  ('002820', '선창산업'),
#  ('003350', '한국화장품제조'),
#  ('019685', '대교우B'),
#  ('100840', 'S&amp;TC'),
#  ('000500', '가온전선'),
#  ('024890', '대원화성'),
#  ('001470', '삼부토건'),
#  ('007540', '샘표'),
#  ('068290', '삼성출판사'),
#  ('002920', '유성기업'),
#  ('016740', '두올'),
#  ('007590', '동방아그로'),
#  ('002700', '신일산업'),
#  ('084670', '동양고속'),
#  ('014440', '영보화학'),
#  ('006980', '우성사료'),
#  ('004410', '서울식품'),
#  ('006805', '미래에셋대우우'),
#  ('120030', '조선선재'),
#  ('018470', '조일알미늄'),
#  ('033180', '필룩스'),
#  ('083420', 'KPX그린케미칼'),
#  ('129260', '인터지스'),
#  ('000590', 'CS홀딩스'),
#  ('001070', '대한방직'),
#  ('012800', '대창'),
#  ('005305', '롯데칠성우'),
#  ('03473K', 'SK우'),
#  ('114100', 'KBSTAR 국고채3년'),
#  ('000890', '보해양조'),
#  ('011785', '금호석유우'),
#  ('014160', '대영포장'),
#  ('530025', '삼성 인버스 인도 Nifty50 선물 ETN(H)'),
#  ('003547', '대신증권2우B'),
#  ('225800', 'KOSEF 미국달러선물 레버리지(합성)'),
#  ('120115', '코오롱인더우'),
#  ('001290', '골든브릿지증권'),
#  ('002210', '동성제약'),
#  ('003610', '방림'),
#  ('155660', 'DSR'),
#  ('004270', '남성'),
#  ('005190', '동성화학'),
#  ('123700', 'SJM'),
#  ('006340', '대원전선'),
#  ('011420', '갤럭시아에스엠'),
#  ('017550', '수산중공업'),
#  ('004100', '태양금속'),
#  ('009070', 'KCTC'),
#  ('003580', '동원'),
#  ('006570', '대림통상'),
#  ('027740', '마니커'),
#  ('140950', '파워 코스피100'),
#  ('074610', '이엔쓰리'),
#  ('023450', '동남합성'),
#  ('239660', 'ARIRANG 우량회사채50 1년'),
#  ('014580', '백광소재'),
#  ('004720', '우리들제약'),
#  ('006125', 'SK케미칼우'),
#  ('008870', '금비'),
#  ('000220', '유유제약'),
#  ('000157', '두산2우B'),
#  ('025820', '이구산업'),
#  ('079660', '사조해표'),
#  ('008250', '이건산업'),
#  ('011330', '유니켐'),
#  ('014990', '인디에프'),
#  ('101140', '아티스'),
#  ('001080', '만호제강'),
#  ('133820', '화인베스틸'),
#  ('078935', 'GS우'),
#  ('245360', 'TIGER 차이나HSCEI'),
#  ('002140', '고려산업'),
#  ('025530', 'SJM홀딩스'),
#  ('114470', 'KOSEF 국고채3년'),
#  ('004090', '한국석유'),
#  ('023350', '한국종합기술'),
#  ('010040', '한국내화'),
#  ('012280', '영화금속'),
#  ('088790', '진도'),
#  ('090080', '평화산업'),
#  ('069730', 'DSR제강'),
#  ('122260', 'KOSEF 통안채1년'),
#  ('005980', '성지건설'),
#  ('009470', '삼화전기'),
#  ('143850', 'TIGER 미국S&amp;P500선물(H)'),
#  ('001275', '부국증권우'),
#  ('002200', '수출포장'),
#  ('001020', '페이퍼코리아'),
#  ('000300', '대유플러스'),
#  ('002720', '국제약품'),
#  ('011500', '한농화성'),
#  ('001260', '남광토건'),
#  ('580001', 'KB 코스피200선물플러스 ETN'),
#  ('530001', '삼성 유럽 고배당 주식 ETN(H)'),
#  ('570001', 'TRUE 코스피 커버드콜 ETN'),
#  ('006880', '신송홀딩스'),
#  ('004770', '써니전자'),
#  ('138230', 'KOSEF 미국달러선물'),
#  ('530031', '삼성 레버리지 WTI원유 선물 ETN'),
#  ('093240', '형지엘리트'),
#  ('010100', '한국프랜지'),
#  ('024070', 'WISCOM'),
#  ('096300', '베트남개발1'),
#  ('580002', 'KB Quant비중조절 ETN'),
#  ('000910', '유니온'),
#  ('580007', 'KB KQ 우량주30 ETN'),
#  ('002690', '동일제강'),
#  ('099140', 'KODEX China H'),
#  ('139250', 'TIGER 200 에너지화학'),
#  ('006740', '영풍제지'),
#  ('009460', '한창제지'),
#  ('002760', '보락'),
#  ('004140', '동방'),
#  ('500001', '신한 K200 USD 선물 바이셀 ETN'),
#  ('001620', '동국실업'),
#  ('580006', 'KB KTOP30 ETN'),
#  ('008420', '문배철강'),
#  ('021050', '서원'),
#  ('026940', '부국철강'),
#  ('145210', '세화아이엠씨'),
#  ('004830', '덕성'),
#  ('108675', 'LG하우시스우'),
#  ('005360', '모나미'),
#  ('001210', '금호전기'),
#  ('119650', 'KC코트렐'),
#  ('003465', '유화증권우'),
#  ('550001', 'QV Big Vol ETN'),
#  ('001550', '조비'),
#  ('001560', '제일연마'),
#  ('137610', 'TIGER 농산물선물Enhanced(H)'),
#  ('590001', '미래에셋 미국 바이백 ETN(H)'),
#  ('072130', '유엔젤'),
#  ('132030', 'KODEX 골드선물(H)'),
#  ('024900', '덕양산업'),
#  ('006890', '태경화학'),
#  ('002070', '남영비비안'),
#  ('007610', '선도전기'),
#  ('015590', '대경기계'),
#  ('031820', '콤텍시스템'),
#  ('002410', '범양건영'),
#  ('123310', 'TIGER 인버스'),
#  ('214330', '금호에이치티'),
#  ('014130', '한익스프레스'),
#  ('136340', 'KBSTAR 중기우량회사채'),
#  ('010770', '평화홀딩스'),
#  ('002710', 'TCC동양'),
#  ('122090', 'ARIRANG 코스피50'),
#  ('002220', '한일철강'),
#  ('005110', '한창'),
#  ('266160', 'KBSTAR 고배당'),
#  ('550002', 'QV WISE 배당 ETN'),
#  ('013360', '일성건설'),
#  ('000760', '이화산업'),
#  ('023150', 'MH에탄올'),
#  ('005820', '원림'),
#  ('500027', '신한 인버스 2X WTI원유 선물 ETN(H)'),
#  ('139270', 'TIGER 200 금융'),
#  ('217780', 'TIGER 차이나CSI300인버스(합성)'),
#  ('005320', '국동'),
#  ('015260', '에이엔피'),
#  ('003010', '혜인'),
#  ('500015', '신한 WTI원유 선물 ETN(H)'),
#  ('169950', 'KODEX 중국본토 A50'),
#  ('010660', '화천기계'),
#  ('145270', '케이탑리츠'),
#  ('023810', '인팩'),
#  ('009190', '대양금속'),
#  ('211900', 'KODEX 배당성장'),
#  ('137930', '마이다스 200커버드콜5%OTM'),
#  ('114820', 'TIGER 국채3년'),
#  ('008110', '대동전자'),
#  ('005450', '신한'),
#  ('013700', '까뮤이앤씨'),
#  ('023960', '에쓰씨엔지니어링'),
#  ('182480', 'TIGER 미국MSCI리츠(합성 H)'),
#  ('007120', '미래아이앤지'),
#  ('007630', '암니스'),
#  ('014910', '성문전자'),
#  ('155900', '바다로19호'),
#  ('020120', '다우인큐브'),
#  ('000520', '삼일제약'),
#  ('182490', 'TIGER 단기선진하이일드(합성 H)'),
#  ('090370', '아비스타'),
#  ('093230', '이아이디'),
#  ('570002', 'TRUE 코스피 커버드풋 ETN'),
#  ('580003', 'KB Monthly Best 11 ETN'),
#  ('044380', '주연테크'),
#  ('009810', '엔케이물산'),
#  ('245710', 'KINDEX 베트남VN30(합성)'),
#  ('003720', '삼영화학'),
#  ('006200', '한국전자홀딩스'),
#  ('174360', 'KBSTAR 중국본토대형주CSI100'),
#  ('275980', 'TIGER 글로벌4차산업혁신기술(합성 H)'),
#  ('071090', '하이스틸'),
#  ('227830', 'ARIRANG 코스피'),
#  ('134790', '팀스'),
#  ('213610', 'KODEX 삼성그룹밸류'),
#  ('006110', '삼아알미늄'),
#  ('015540', '메디플란트'),
#  ('027970', '세하'),
#  ('000105', '유한양행우'),
#  ('002355', '넥센타이어1우B'),
#  ('011300', '성안'),
#  ('013000', '세우글로벌'),
#  ('003780', '진양산업'),
#  ('118000', '우리들휴브레인'),
#  ('520004', '미래에셋 전기전자 Core5 ETN'),
#  ('015020', '이스타코'),
#  ('011230', '삼화전자'),
#  ('007280', '한국특수형강'),
#  ('003680', '한성기업'),
#  ('069460', '대호에이엘'),
#  ('009180', '한솔로지스틱스'),
#  ('005030', '부산주공'),
#  ('550009', 'QV 하드웨어 TOP5 ETN'),
#  ('550020', 'QV 2차전지 테마 ETN'),
#  ('011390', '부산산업'),
#  ('500002', '신한 USD K200 선물 바이셀 ETN'),
#  ('030720', '동원수산'),
#  ('003925', '남양유업우'),
#  ('071950', '코아스'),
#  ('001465', 'BYC우'),
#  ('580004', 'KB KQ Monthly Best 11 ETN'),
#  ('010580', '지코'),
#  ('114260', 'KODEX 국고채3년'),
#  ('211560', 'TIGER 배당성장'),
#  ('000950', '전방'),
#  ('226980', 'KODEX 200 중소형'),
#  ('108450', 'KINDEX 삼성그룹섹터가중'),
#  ('123320', 'TIGER 레버리지'),
#  ('004920', '씨아이테크'),
#  ('099340', '하나니켈1호'),
#  ('195930', 'TIGER 유로스탁스50(합성 H)'),
#  ('008775', '호텔신라우'),
#  ('174350', 'TIGER 로우볼'),
#  ('530023', '삼성 레버리지 China A50 선물 ETN(H)'),
#  ('500020', '신한 레버리지 다우존스지수 선물 ETN(H)'),
#  ('019180', '티에이치엔'),
#  ('007460', '나라케이아이씨'),
#  ('204450', 'KODEX China H 레버리지(H)'),
#  ('008500', '일정실업'),
#  ('009140', '경인전자'),
#  ('012600', '청호컴넷'),
#  ('204210', '모두투어리츠'),
#  ('530012', '삼성 화학 테마주 ETN'),
#  ('192720', '파워 고배당저변동성'),
#  ('002870', '신풍제지'),
#  ('025890', '한국주강'),
#  ('010600', '와이비로드'),
#  ('003475', '유안타증권우'),
#  ('140890', '트러스제7호'),
#  ('010420', '한솔PNS'),
#  ('520006', '미래에셋 에너지화학 Core5 ETN'),
#  ('195920', 'TIGER 일본TOPIX(합성 H)'),
#  ('002025', '코오롱우'),
#  ('002420', '세기상사'),
#  ('500021', '신한 천연가스 선물 ETN(H)'),
#  ('172580', '하이골드12호'),
#  ('261250', 'KODEX 미국달러선물레버리지'),
#  ('051630', '진양화학'),
#  ('233160', 'TIGER 코스닥150 레버리지'),
#  ('590010', '미래에셋 레버리지 S&amp;P500 ETN(H)'),
#  ('108590', 'TREX 200'),
#  ('530032', '삼성 Cushing 에너지인프라 MLP ETN'),
#  ('570007', 'TRUE 위안화 중국5년국채 ETN'),
#  ('004365', '세방우'),
#  ('001420', '태원물산'),
#  ('530033', '삼성 Alerian 에너지인프라 MLP ETN'),
#  ('590009', '미래에셋 미국 항공우주 ETN(H)'),
#  ('153360', '하이골드3호'),
#  ('215620', '흥국 S&amp;P코리아로우볼'),
#  ('550013', 'QV 화학 TOP5 ETN'),
#  ('500018', '신한 구리 선물 ETN(H)'),
#  ('219900', 'KINDEX 중국본토CSI300레버리지(합성)'),
#  ('520003', '미래에셋 원자재 선물 ETN(H)'),
#  ('550008', 'QV 소프트웨어 TOP5 ETN'),
#  ('109070', 'KGP'),
#  ('033250', '체시스'),
#  ('243880', 'TIGER 200IT레버리지'),
#  ('170350', 'TIGER 베타플러스'),
#  ('580005', 'KB 우량주 Monthly Best 11 ETN'),
#  ('550029', 'QV 대체에너지 테마 ETN'),
#  ('550005', 'QV 에너지 TOP5 ETN'),
#  ('550019', 'QV 전기차 테마 ETN'),
#  ('520014', '미래에셋 미디어엔터 Core5 ETN'),
#  ('570005', 'TRUE 목표변동성20 코스피선물 ETN'),
#  ('590005', '미래에셋 일본 대형주 ETN(H)'),
#  ('211210', '마이티 코스피고배당'),
#  ('500009', '신한 다우존스지수 선물 ETN(H)'),
#  ('590006', '미래에셋 일본 중형주 ETN(H)'),
#  ('019490', '하이트론'),
#  ('530014', '삼성 China A50 선물 ETN(H)'),
#  ('500003', '신한 인버스 WTI원유 선물 ETN(H)'),
#  ('550026', 'QV KTOP30 ETN'),
#  ('590007', '미래에셋 미국 대형주 ETN(H)'),
#  ('520002', '미래에셋 차이나 대표주 15 ETN(H)'),
#  ('550030', 'QV OLED 테마 ETN'),
#  ('570015', 'TRUE 다우존스 지속가능경영 코리아 ETN'),
#  ('590008', '미래에셋 미국 중형주 ETN(H)'),
#  ('500014', '신한 인버스 옥수수 선물 ETN(H)'),
#  ('520013', '미래에셋 Q150 Core5 ETN'),
#  ('225130', 'KINDEX 골드선물 레버리지(합성 H)'),
#  ('253250', 'KOSEF 200선물레버리지'),
#  ('550014', 'QV 바이오 TOP5 ETN'),
#  ('530015', '삼성 미국 대형 성장주 ETN(H)'),
#  ('570003', 'TRUE 빅5 동일가중 ETN'),
#  ('144600', 'KODEX 은선물(H)'),
#  ('530016', '삼성 미국 대형 가치주 ETN(H)'),
#  ('520001', '미래에셋 로우볼 ETN'),
#  ('590018', '미래에셋 중국 심천 100 ETN'),
#  ('590003', '미래에셋 유럽 대형주 ETN(H)'),
#  ('590004', '미래에셋 유럽 중형주 ETN(H)'),
#  ('530017', '삼성 미국 중소형 성장주 ETN(H)'),
#  ('252650', 'KODEX 200동일가중'),
#  ('550011', 'QV 자동차 TOP5 ETN'),
#  ('530019', '삼성 미국 대형 성장주 ETN'),
#  ('530018', '삼성 미국 중소형 가치주 ETN(H)'),
#  ('500005', '신한 인버스 브렌트원유 선물 ETN(H)'),
#  ('530020', '삼성 미국 대형 가치주 ETN'),
#  ('229720', 'KODEX KTOP30'),
#  ('530021', '삼성 미국 중소형 성장주 ETN'),
#  ('590002', '미래에셋 일본 바이백 ETN(H)'),
#  ('500022', '신한 인버스 천연가스 선물 ETN(H)'),
#  ('252400', 'KBSTAR 200선물레버리지'),
#  ('530022', '삼성 미국 중소형 가치주 ETN'),
#  ('570008', 'TRUE 섹터탑픽 ETN'),
#  ('251600', 'ARIRANG 고배당주채권혼합'),
#  ('530005', '삼성 바이오 테마주 ETN'),
#  ('001770', '신화실업'),
#  ('550004', 'QV 롱숏 K150 매수 로우볼 매도 ETN'),
#  ('590016', '미래에셋 미국 헬스케어 ETN(H)'),
#  ('230480', 'KOSEF 미국달러선물 인버스2X(합성)'),
#  ('237350', 'KODEX 코스피100'),
#  ('570009', 'TRUE 코리아프리미어 ETN'),
#  ('176950', 'KODEX 국채선물10년인버스'),
#  ('500016', '신한 금 선물 ETN(H)'),
#  ('500030', '신한 인버스 2X 은 선물 ETN(H)'),
#  ('000087', '하이트진로2우B'),
#  ('590017', '미래에셋 미국 고배당주 ETN(H)'),
#  ('550042', 'QV 레버리지 WTI원유 선물 ETN(H)'),
#  ('550024', 'QV 수자원 테마 ETN'),
#  ('251590', 'ARIRANG 고배당저변동50'),
#  ('570012', 'TRUE 인버스 엔선물 ETN'),
#  ('520012', '미래에셋 호주 ASX200 ETN(H)'),
#  ('005257', '녹십자홀딩스2우'),
#  ...]

# %%
# Creating funcions to crawl each type of fiann

# %%
# looping and crawl - use 'yield' 
for item in [code[0] for code in code_n_name]:
    # open a webpage
    driver.get('http://finance.naver.com/item/coinfo.nhn?code={0}').format(item)
    
    # move to a relavent frame
    frame = driver.find_element_by_css_selector("#coinfo_cp")
    driver.swtich_to.frame(frame)
    
    # click a relavent tab and button - income statement 
    finstate_button = driver.find_element_by_css_selector("#header-menu > div.wrapper-menu > dl > dt:nth-of-type(3) > a")
    finstate_button.click()
    
    # About income statement 
    html_income = driver.page_source
    soup_income = BeautifulSoul(html_income, 'lxml')
# Out:
# 005930
# 000660
# 005935
# 005380
# 005490
# 051910
# 035420
# 028260
# 015760
# 055550
# 105560
# 032830
# 207940
# 012330
# 017670
# 034730
# 096770
# 006400
# 090430
# 033780
# 066570
# 086790
# 003550
# 051900
# 010950
# 251270
# 018260
# 011170
# 000810
# 000270
# 000030
# 034220
# 002790
# 036570
# 035720
# 010130
# 009540
# 024110
# 009150
# 030200
# 035250
# 161390
# 021240
# 004020
# 267250
# 006800
# 023530
# 018880
# 009830
# 078930
# 088350
# 139480
# 008930
# 032640
# 069500
# 086280
# 004800
# 001040
# 005830
# 128940
# 042660
# 097950
# 047810
# 000720
# 010140
# 029780
# 002380
# 001450
# 036460
# 027410
# 005940
# 011070
# 271560
# 005387
# 241560
# 009240
# 071050
# 000120
# 079440
# 000880
# 012750
# 138930
# 028670
# 016360
# 003490
# 047040
# 008560
# 000210
# 088980
# 007070
# 000150
# 004990
# 012630
# 000060
# 000100
# 010060
# 006260
# 026960
# 047050
# 007310
# 102110
# 006280
# 011780
# 005385
# 204320
# 138040
# 008770
# 000670
# 028050
# 030000
# 004370
# 069960
# 006360
# 051915
# 000240
# 122630
# 010620
# 003520
# 012450
# 120110
# 051600
